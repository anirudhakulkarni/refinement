# %% [markdown]
# # **Optimizing AUROC loss on imbalanced dataset**
#
# * Author: Zhuoning Yuan
#
# **Useful Resources**:
# * Website: https://libauc.org
# * Github: https://github.com/Optimization-AI/LibAUC
#
# **Reference**:
#
# If you find this tutorial helpful in your work,  please acknowledge our library and cite the following paper:
# ```
# @inproceedings{yuan2021large,
#   title={Large-scale robust deep auc maximization: A new surrogate loss and empirical studies on medical image classification},
#   author={Yuan, Zhuoning and Yan, Yan and Sonka, Milan and Yang, Tianbao},
#   booktitle={Proceedings of the IEEE/CVF International Conference on Computer Vision},
#   pages={3040--3049},
#   year={2021}
# }
#
# @misc{libauc2022,
#       title={LibAUC: A Deep Learning Library for X-Risk Optimization.},
#       author={Zhuoning Yuan, Zi-Hao Qiu, Gang Li, Dixian Zhu, Zhishuai Guo, Quanqi Hu, Bokun Wang, Qi Qi, Yongjian Zhong, Tianbao Yang},
#       year={2022}
#     }
# ```

# %% [markdown]
# # **Installing LibAUC**

# %%
# !pip install libauc.whl
# Out:
# ERROR: libauc.whl is not a valid wheel filename.

# %% [markdown]
# # **Importing LibAUC**

# %%
import libauc

# %%
from libauc.losses import AUCMLoss
from libauc.optimizers import PESG
from libauc.models import resnet20 as ResNet20
from libauc.datasets import CIFAR10
from libauc.utils import ImbalancedDataGenerator
from libauc.sampler import DualSampler

import torch 
from PIL import Image
import numpy as np
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # **Reproducibility**

# %%
def set_all_seeds(SEED):
    # REPRODUCIBILITY
    torch.manual_seed(SEED)
    np.random.seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # **Image Dataset**

# %%
class ImageDataset(Dataset):
    def __init__(self, images, targets, image_size=32, crop_size=30, mode='train'):
       self.images = images.astype(np.uint8)
       self.targets = targets
       self.mode = mode
       self.transform_train = transforms.Compose([                                                
                              transforms.ToTensor(),
                              transforms.RandomCrop((crop_size, crop_size), padding=None),
                              transforms.RandomHorizontalFlip(),
                              transforms.Resize((image_size, image_size)),
                              ])
       self.transform_test = transforms.Compose([
                             transforms.ToTensor(),
                             transforms.Resize((image_size, image_size)),
                              ])
    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        target = self.targets[idx]
        image = Image.fromarray(image.astype('uint8'))
        if self.mode == 'train':
            image = self.transform_train(image)
        else:
            image = self.transform_test(image)
        return image, target

# %% [markdown]
# # **Paramaters**

# %%
# paramaters
SEED = 123
BATCH_SIZE = 128
imratio = 0.1 # for demo 
lr = 0.1
gamma = 500
weight_decay = 1e-4
margin = 1.0

# %% [markdown]
# # **Loading datasets**

# %%
# dataloader 
train_data, train_targets = CIFAR10(root='./data', train=True)
test_data, test_targets  = CIFAR10(root='./data', train=False)

generator = ImbalancedDataGenerator(verbose=True, random_seed=0)
(train_images, train_labels) = generator.transform(train_data, train_targets, imratio=imratio)
(test_images, test_labels) = generator.transform(test_data, test_targets, imratio=0.5) 

trainloader = torch.utils.data.DataLoader(ImageDataset(train_images, train_labels), batch_size=BATCH_SIZE, shuffle=True, num_workers=1, pin_memory=True, drop_last=True)
testloader = torch.utils.data.DataLoader( ImageDataset(test_images, test_labels, mode='test'), batch_size=BATCH_SIZE, shuffle=False, num_workers=1,  pin_memory=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# #SAMPLES: [27777], POS:NEG: [2777 : 25000], POS RATIO: 0.1000
# #SAMPLES: [10000], POS:NEG: [5000 : 5000], POS RATIO: 0.5000

# %% [markdown]
# # **Creating models & AUC Optimizer**

# %%
# You need to include sigmoid activation in the last layer for any customized models!
model = ResNet20(pretrained=False, last_activation=None, num_classes=1)
model = model.cuda()

Loss = AUCMLoss()
optimizer = PESG(model, 
                 a=Loss.a, 
                 b=Loss.b, 
                 alpha=Loss.alpha, 
                 lr=lr, 
                 gamma=gamma, 
                 margin=margin, 
                 weight_decay=weight_decay)

# %% [markdown]
# # **Training**

# %%
print ('Start Training')
print ('-'*30)
best=[0,0,0,0]

for epoch in range(100):
    
     if epoch == 50 or epoch==75:
         # decrease learning rate by 10x & update regularizer
         optimizer.update_regularizer(decay_factor=10)
   
     train_pred = []
     train_true = []
     model.train()    
     for data, targets in trainloader:
         data, targets  = data.cuda(), targets.cuda()
         y_pred = model(data)
         y_pred = torch.sigmoid(y_pred)
         loss = Loss(y_pred, targets)
         optimizer.zero_grad()
         loss.backward()
         optimizer.step()
        
         train_pred.append(y_pred.cpu().detach().numpy())
         train_true.append(targets.cpu().detach().numpy())

     train_true = np.concatenate(train_true)
     train_pred = np.concatenate(train_pred)
    #  print(train_true)
    #  print(train_pred)
     train_auc = roc_auc_score(train_true, train_pred) 

     model.eval()
     test_pred = []
     test_true = [] 
     for j, data in enumerate(testloader):
         test_data, test_targets = data
         test_data = test_data.cuda()
         y_pred = model(test_data)
         test_pred.append(y_pred.cpu().detach().numpy())
         test_true.append(test_targets.numpy())
     test_true = np.concatenate(test_true)
     test_pred = np.concatenate(test_pred)
     val_auc =  roc_auc_score(test_true, test_pred) 
     model.train()
     if best==[0,0,0,0] or val_auc>best[3]:
        best = [gamma, margin, train_auc, val_auc]
        torch.save(model.state_dict(), "cifar10_resnet20_AUCM_im10_"+str(SEED)+".pth")
   
     # print results
     print("epoch: {}, train_loss: {:4f}, train_auc:{:4f}, test_auc:{:4f}, lr:{:4f}".format(epoch, loss.item(), train_auc, val_auc, optimizer.lr ))
# Out:
# Start Training
# ------------------------------
# epoch: 0, train_loss: 0.090208, train_auc:0.573331, test_auc:0.629015, lr:0.100000
# epoch: 1, train_loss: 0.030757, train_auc:0.642354, test_auc:0.659973, lr:0.100000
# epoch: 2, train_loss: 0.083005, train_auc:0.666582, test_auc:0.651599, lr:0.100000
# epoch: 3, train_loss: 0.070119, train_auc:0.688259, test_auc:0.640883, lr:0.100000
# epoch: 4, train_loss: 0.089829, train_auc:0.704402, test_auc:0.653463, lr:0.100000
# epoch: 5, train_loss: 0.063096, train_auc:0.719854, test_auc:0.651552, lr:0.100000
# epoch: 6, train_loss: 0.070863, train_auc:0.725587, test_auc:0.679529, lr:0.100000
# epoch: 7, train_loss: 0.061029, train_auc:0.737369, test_auc:0.709401, lr:0.100000
# epoch: 8, train_loss: 0.043147, train_auc:0.747870, test_auc:0.682861, lr:0.100000
# epoch: 9, train_loss: 0.051880, train_auc:0.758344, test_auc:0.719271, lr:0.100000
# epoch: 10, train_loss: 0.063217, train_auc:0.767074, test_auc:0.708508, lr:0.100000
# epoch: 11, train_loss: 0.029323, train_auc:0.777087, test_auc:0.738076, lr:0.100000
# epoch: 12, train_loss: 0.041064, train_auc:0.778552, test_auc:0.744162, lr:0.100000
# epoch: 13, train_loss: 0.065296, train_auc:0.790880, test_auc:0.747207, lr:0.100000
# epoch: 14, train_loss: 0.037670, train_auc:0.798582, test_auc:0.782210, lr:0.100000
# epoch: 15, train_loss: 0.033747, train_auc:0.805956, test_auc:0.720104, lr:0.100000
# epoch: 16, train_loss: 0.066441, train_auc:0.810287, test_auc:0.755065, lr:0.100000
# epoch: 17, train_loss: 0.050975, train_auc:0.814392, test_auc:0.752824, lr:0.100000
# epoch: 18, train_loss: 0.029185, train_auc:0.821327, test_auc:0.770460, lr:0.100000
# epoch: 19, train_loss: 0.122134, train_auc:0.825028, test_auc:0.716856, lr:0.100000
# epoch: 20, train_loss: 0.039428, train_auc:0.829837, test_auc:0.813118, lr:0.100000
# epoch: 21, train_loss: 0.029954, train_auc:0.840307, test_auc:0.768955, lr:0.100000
# epoch: 22, train_loss: 0.047369, train_auc:0.836519, test_auc:0.769632, lr:0.100000
# epoch: 23, train_loss: 0.056089, train_auc:0.843317, test_auc:0.692083, lr:0.100000
# epoch: 24, train_loss: 0.023519, train_auc:0.843984, test_auc:0.818166, lr:0.100000
# epoch: 25, train_loss: 0.021550, train_auc:0.850949, test_auc:0.775064, lr:0.100000
# epoch: 26, train_loss: 0.058791, train_auc:0.855809, test_auc:0.801082, lr:0.100000
# epoch: 27, train_loss: 0.049214, train_auc:0.860092, test_auc:0.785790, lr:0.100000
# epoch: 28, train_loss: 0.082673, train_auc:0.862349, test_auc:0.831529, lr:0.100000
# epoch: 29, train_loss: 0.035575, train_auc:0.861351, test_auc:0.817325, lr:0.100000
# epoch: 30, train_loss: 0.020660, train_auc:0.867675, test_auc:0.817030, lr:0.100000
# epoch: 31, train_loss: 0.028318, train_auc:0.866058, test_auc:0.798891, lr:0.100000
# epoch: 32, train_loss: 0.049333, train_auc:0.873599, test_auc:0.788959, lr:0.100000
# epoch: 33, train_loss: 0.061755, train_auc:0.873266, test_auc:0.767104, lr:0.100000
# epoch: 34, train_loss: 0.033943, train_auc:0.873377, test_auc:0.829278, lr:0.100000
# epoch: 35, train_loss: 0.039626, train_auc:0.883130, test_auc:0.826154, lr:0.100000
# epoch: 36, train_loss: 0.050324, train_auc:0.883266, test_auc:0.584755, lr:0.100000
# epoch: 37, train_loss: 0.029031, train_auc:0.877065, test_auc:0.848019, lr:0.100000
# epoch: 38, train_loss: 0.025323, train_auc:0.884422, test_auc:0.785901, lr:0.100000
# epoch: 39, train_loss: 0.043038, train_auc:0.887169, test_auc:0.827401, lr:0.100000
# epoch: 40, train_loss: 0.040884, train_auc:0.888943, test_auc:0.856119, lr:0.100000
# epoch: 41, train_loss: 0.052229, train_auc:0.890483, test_auc:0.833541, lr:0.100000
# epoch: 42, train_loss: 0.021364, train_auc:0.892983, test_auc:0.837608, lr:0.100000
# epoch: 43, train_loss: 0.035449, train_auc:0.895845, test_auc:0.833994, lr:0.100000
# epoch: 44, train_loss: 0.041123, train_auc:0.895979, test_auc:0.790587, lr:0.100000
# epoch: 45, train_loss: 0.033726, train_auc:0.897472, test_auc:0.839843, lr:0.100000
# epoch: 46, train_loss: 0.045436, train_auc:0.896196, test_auc:0.801686, lr:0.100000
# epoch: 47, train_loss: 0.023122, train_auc:0.896633, test_auc:0.850945, lr:0.100000
# epoch: 48, train_loss: 0.046027, train_auc:0.898952, test_auc:0.848208, lr:0.100000
# epoch: 49, train_loss: 0.021871, train_auc:0.900335, test_auc:0.835074, lr:0.100000
# Reducing learning rate to 0.01000 @ T=10850!
# Updating regularizer @ T=10850!
# epoch: 50, train_loss: 0.027714, train_auc:0.932560, test_auc:0.888477, lr:0.010000
# epoch: 51, train_loss: 0.025536, train_auc:0.944265, test_auc:0.894424, lr:0.010000
# epoch: 52, train_loss: 0.012866, train_auc:0.945236, test_auc:0.887358, lr:0.010000
# epoch: 53, train_loss: 0.023192, train_auc:0.949485, test_auc:0.893869, lr:0.010000
# epoch: 54, train_loss: 0.020598, train_auc:0.951223, test_auc:0.891916, lr:0.010000
# epoch: 55, train_loss: 0.018366, train_auc:0.951869, test_auc:0.894143, lr:0.010000
# epoch: 56, train_loss: 0.015271, train_auc:0.954179, test_auc:0.892526, lr:0.010000
# epoch: 57, train_loss: 0.035188, train_auc:0.954773, test_auc:0.896054, lr:0.010000
# epoch: 58, train_loss: 0.009633, train_auc:0.955480, test_auc:0.891220, lr:0.010000
# epoch: 59, train_loss: 0.018321, train_auc:0.957697, test_auc:0.891863, lr:0.010000
# epoch: 60, train_loss: 0.010822, train_auc:0.957358, test_auc:0.893536, lr:0.010000
# epoch: 61, train_loss: 0.027686, train_auc:0.957950, test_auc:0.894047, lr:0.010000
# epoch: 62, train_loss: 0.030779, train_auc:0.961168, test_auc:0.895333, lr:0.010000
# epoch: 63, train_loss: 0.025503, train_auc:0.961973, test_auc:0.891963, lr:0.010000
# epoch: 64, train_loss: 0.020830, train_auc:0.962417, test_auc:0.896659, lr:0.010000
# epoch: 65, train_loss: 0.014954, train_auc:0.961193, test_auc:0.892407, lr:0.010000
# epoch: 66, train_loss: 0.003828, train_auc:0.964856, test_auc:0.894351, lr:0.010000
# epoch: 67, train_loss: 0.010680, train_auc:0.963716, test_auc:0.892490, lr:0.010000
# epoch: 68, train_loss: 0.015901, train_auc:0.964565, test_auc:0.897115, lr:0.010000
# epoch: 69, train_loss: 0.010790, train_auc:0.966161, test_auc:0.892596, lr:0.010000
# epoch: 70, train_loss: 0.027938, train_auc:0.966039, test_auc:0.892452, lr:0.010000
# epoch: 71, train_loss: 0.008372, train_auc:0.967816, test_auc:0.897165, lr:0.010000
# epoch: 72, train_loss: 0.021913, train_auc:0.966662, test_auc:0.890643, lr:0.010000
# epoch: 73, train_loss: 0.005522, train_auc:0.967424, test_auc:0.889214, lr:0.010000
# epoch: 74, train_loss: 0.007252, train_auc:0.966605, test_auc:0.893920, lr:0.010000
# Reducing learning rate to 0.00100 @ T=16275!
# Updating regularizer @ T=16275!
# epoch: 75, train_loss: 0.017496, train_auc:0.969682, test_auc:0.894108, lr:0.001000
# epoch: 76, train_loss: 0.020484, train_auc:0.970625, test_auc:0.892950, lr:0.001000
# epoch: 77, train_loss: 0.007340, train_auc:0.972725, test_auc:0.894101, lr:0.001000
# epoch: 78, train_loss: 0.012687, train_auc:0.970766, test_auc:0.892946, lr:0.001000
# epoch: 79, train_loss: 0.011247, train_auc:0.970565, test_auc:0.894000, lr:0.001000
# epoch: 80, train_loss: 0.021281, train_auc:0.971728, test_auc:0.895509, lr:0.001000
# epoch: 81, train_loss: 0.013654, train_auc:0.972018, test_auc:0.895095, lr:0.001000
# epoch: 82, train_loss: 0.006842, train_auc:0.971392, test_auc:0.894939, lr:0.001000
# epoch: 83, train_loss: 0.013886, train_auc:0.972021, test_auc:0.895543, lr:0.001000
# epoch: 84, train_loss: 0.028114, train_auc:0.972590, test_auc:0.893512, lr:0.001000
# epoch: 85, train_loss: 0.028626, train_auc:0.972248, test_auc:0.894290, lr:0.001000
# epoch: 86, train_loss: 0.009146, train_auc:0.971922, test_auc:0.894512, lr:0.001000
# epoch: 87, train_loss: 0.015380, train_auc:0.972042, test_auc:0.894444, lr:0.001000
# epoch: 88, train_loss: 0.022290, train_auc:0.972514, test_auc:0.894284, lr:0.001000
# epoch: 89, train_loss: 0.006996, train_auc:0.972130, test_auc:0.893981, lr:0.001000
# epoch: 90, train_loss: 0.007630, train_auc:0.971110, test_auc:0.894605, lr:0.001000
# epoch: 91, train_loss: 0.005002, train_auc:0.972589, test_auc:0.894681, lr:0.001000
# epoch: 92, train_loss: 0.016185, train_auc:0.972496, test_auc:0.894084, lr:0.001000
# epoch: 93, train_loss: 0.008399, train_auc:0.972597, test_auc:0.894346, lr:0.001000
# epoch: 94, train_loss: 0.010298, train_auc:0.973534, test_auc:0.893808, lr:0.001000
# epoch: 95, train_loss: 0.011431, train_auc:0.971797, test_auc:0.894036, lr:0.001000
# epoch: 96, train_loss: 0.014136, train_auc:0.972664, test_auc:0.894420, lr:0.001000
# epoch: 97, train_loss: 0.008886, train_auc:0.972911, test_auc:0.893422, lr:0.001000
# epoch: 98, train_loss: 0.005530, train_auc:0.972768, test_auc:0.894280, lr:0.001000
# epoch: 99, train_loss: 0.008489, train_auc:0.972519, test_auc:0.893849, lr:0.001000
