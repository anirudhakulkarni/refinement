# %% [markdown]
# # **Optimizing AUROC loss on imbalanced dataset**
#
# * Author: Zhuoning Yuan
#
# **Useful Resources**:
# * Website: https://libauc.org
# * Github: https://github.com/Optimization-AI/LibAUC
#
# **Reference**:
#
# If you find this tutorial helpful in your work,  please acknowledge our library and cite the following paper:
# ```
# @inproceedings{yuan2021large,
#   title={Large-scale robust deep auc maximization: A new surrogate loss and empirical studies on medical image classification},
#   author={Yuan, Zhuoning and Yan, Yan and Sonka, Milan and Yang, Tianbao},
#   booktitle={Proceedings of the IEEE/CVF International Conference on Computer Vision},
#   pages={3040--3049},
#   year={2021}
# }
#
# @misc{libauc2022,
#       title={LibAUC: A Deep Learning Library for X-Risk Optimization.},
#       author={Zhuoning Yuan, Zi-Hao Qiu, Gang Li, Dixian Zhu, Zhishuai Guo, Quanqi Hu, Bokun Wang, Qi Qi, Yongjian Zhong, Tianbao Yang},
#       year={2022}
#     }
# ```

# %% [markdown]
# # **Installing LibAUC**

# %%
# !pip install libauc.whl
# Out:
# WARNING: Requirement 'libauc.whl' looks like a filename, but the file does not exist
# ERROR: libauc.whl is not a valid wheel filename.

# %% [markdown]
# # **Importing LibAUC**

# %%
import libauc

# %%
from libauc.losses import AUCMLoss
from libauc.optimizers import PESG
from libauc.models import resnet20 as ResNet20
from libauc.datasets import CIFAR10
from libauc.utils import ImbalancedDataGenerator
from libauc.sampler import DualSampler

import torch 
from PIL import Image
import numpy as np
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # **Reproducibility**

# %%
def set_all_seeds(SEED):
    # REPRODUCIBILITY
    torch.manual_seed(SEED)
    np.random.seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # **Image Dataset**

# %%
class ImageDataset(Dataset):
    def __init__(self, images, targets, image_size=32, crop_size=30, mode='train'):
       self.images = images.astype(np.uint8)
       self.targets = targets
       self.mode = mode
       self.transform_train = transforms.Compose([                                                
                              transforms.ToTensor(),
                              transforms.RandomCrop((crop_size, crop_size), padding=None),
                              transforms.RandomHorizontalFlip(),
                              transforms.Resize((image_size, image_size)),
                              ])
       self.transform_test = transforms.Compose([
                             transforms.ToTensor(),
                             transforms.Resize((image_size, image_size)),
                              ])
    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        target = self.targets[idx]
        image = Image.fromarray(image.astype('uint8'))
        if self.mode == 'train':
            image = self.transform_train(image)
        else:
            image = self.transform_test(image)
        return image, target

# %% [markdown]
# # **Paramaters**

# %%
# paramaters
SEED = 123
BATCH_SIZE = 128
imratio = 0.1 # for demo 
lr = 0.1
gamma = 500
weight_decay = 1e-4
margin = 1.0

# %% [markdown]
# # **Loading datasets**

# %%
# dataloader 
train_data, train_targets = CIFAR10(root='./data', train=True)
test_data, test_targets  = CIFAR10(root='./data', train=False)

generator = ImbalancedDataGenerator(verbose=True, random_seed=0)
(train_images, train_labels) = generator.transform(train_data, train_targets, imratio=imratio)
(test_images, test_labels) = generator.transform(test_data, test_targets, imratio=0.5) 

trainloader = torch.utils.data.DataLoader(ImageDataset(train_images, train_labels), batch_size=BATCH_SIZE, shuffle=True, num_workers=1, pin_memory=True, drop_last=True)
testloader = torch.utils.data.DataLoader( ImageDataset(test_images, test_labels, mode='test'), batch_size=BATCH_SIZE, shuffle=False, num_workers=1,  pin_memory=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# #SAMPLES: [27777], POS:NEG: [2777 : 25000], POS RATIO: 0.1000
# #SAMPLES: [10000], POS:NEG: [5000 : 5000], POS RATIO: 0.5000

# %% [markdown]
# # **Creating models & AUC Optimizer**

# %%
# You need to include sigmoid activation in the last layer for any customized models!
model = ResNet20(pretrained=False, last_activation=None, num_classes=1)
model = model.cuda()
from libauc.losses import AUCMLoss, CrossEntropyLoss

Loss = CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr,
                                         weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.MultiStepLR(
        optimizer, milestones=[50,75], gamma=0.1)

# %% [markdown]
# # **Training**

# %%
print ('Start Training')
print ('-'*30)
best=[0,0,0,0]

for epoch in range(100):
    
     if epoch == 50 or epoch==75:
         # decrease learning rate by 10x & update regularizer
         optimizer.update_regularizer(decay_factor=10)
   
     train_pred = []
     train_true = []
     model.train()    
     for data, targets in trainloader:
         data, targets  = data.cuda(), targets.cuda()
         y_pred = model(data)
        #  y_pred = torch.sigmoid(y_pred)
         loss = Loss(y_pred, targets)
         optimizer.zero_grad()
         loss.backward()
         optimizer.step()
        
         train_pred.append(y_pred.cpu().detach().numpy())
         train_true.append(targets.cpu().detach().numpy())

     train_true = np.concatenate(train_true)
     train_pred = np.concatenate(train_pred)
    #  print(train_true)
    #  print(train_pred)
     train_auc = roc_auc_score(train_true, train_pred) 

     model.eval()
     test_pred = []
     test_true = [] 
     for j, data in enumerate(testloader):
         test_data, test_targets = data
         test_data = test_data.cuda()
         y_pred = model(test_data)
         test_pred.append(y_pred.cpu().detach().numpy())
         test_true.append(test_targets.numpy())
     test_true = np.concatenate(test_true)
     test_pred = np.concatenate(test_pred)
     val_auc =  roc_auc_score(test_true, test_pred) 
     model.train()
     scheduler.step()
     if best==[0,0,0,0] or val_auc>best[3]:
        best = [gamma, margin, train_auc, val_auc]
        torch.save(model.state_dict(), "cifar10_resnet20_CE_im10_"+str(SEED)+".pth")

     # print results
     print("epoch: {}, train_loss: {:4f}, train_auc:{:4f}, test_auc:{:4f}".format(epoch, loss.item(), train_auc, val_auc ))
# Out:
# Start Training
# ------------------------------
# epoch: 0, train_loss: 0.322058, train_auc:0.590665, test_auc:0.641085
# epoch: 1, train_loss: 0.305575, train_auc:0.653737, test_auc:0.662776
# epoch: 2, train_loss: 0.279321, train_auc:0.682465, test_auc:0.701008
# epoch: 3, train_loss: 0.295344, train_auc:0.708377, test_auc:0.668417
# epoch: 4, train_loss: 0.305138, train_auc:0.728125, test_auc:0.750032
# epoch: 5, train_loss: 0.318154, train_auc:0.748305, test_auc:0.768377
# epoch: 6, train_loss: 0.386805, train_auc:0.760233, test_auc:0.741898
# epoch: 7, train_loss: 0.303999, train_auc:0.777376, test_auc:0.773723
# epoch: 8, train_loss: 0.181465, train_auc:0.791258, test_auc:0.786716
# epoch: 9, train_loss: 0.218767, train_auc:0.803981, test_auc:0.794400
# epoch: 10, train_loss: 0.349656, train_auc:0.812973, test_auc:0.796529
# epoch: 11, train_loss: 0.242755, train_auc:0.825000, test_auc:0.785021
# epoch: 12, train_loss: 0.211447, train_auc:0.831695, test_auc:0.815711
# epoch: 13, train_loss: 0.230614, train_auc:0.845277, test_auc:0.821643
# epoch: 14, train_loss: 0.192664, train_auc:0.850815, test_auc:0.817596
# epoch: 15, train_loss: 0.199965, train_auc:0.858041, test_auc:0.832340
# epoch: 16, train_loss: 0.207231, train_auc:0.863944, test_auc:0.803580
# epoch: 17, train_loss: 0.146700, train_auc:0.871141, test_auc:0.826417
# epoch: 18, train_loss: 0.158988, train_auc:0.879901, test_auc:0.843403
# epoch: 19, train_loss: 0.231616, train_auc:0.881308, test_auc:0.850740
# epoch: 20, train_loss: 0.222660, train_auc:0.887016, test_auc:0.836679
# epoch: 21, train_loss: 0.219835, train_auc:0.896037, test_auc:0.833657
# epoch: 22, train_loss: 0.262434, train_auc:0.898267, test_auc:0.836956
# epoch: 23, train_loss: 0.184699, train_auc:0.901824, test_auc:0.851801
# epoch: 24, train_loss: 0.181128, train_auc:0.907372, test_auc:0.836857
# epoch: 25, train_loss: 0.215549, train_auc:0.912315, test_auc:0.850119
# epoch: 26, train_loss: 0.100099, train_auc:0.914185, test_auc:0.854045
# epoch: 27, train_loss: 0.216677, train_auc:0.921466, test_auc:0.834968
# epoch: 28, train_loss: 0.237514, train_auc:0.920723, test_auc:0.847286
# epoch: 29, train_loss: 0.120821, train_auc:0.925356, test_auc:0.829689
# epoch: 30, train_loss: 0.179717, train_auc:0.926474, test_auc:0.870379
# epoch: 31, train_loss: 0.287968, train_auc:0.933315, test_auc:0.852683
# epoch: 32, train_loss: 0.138135, train_auc:0.936592, test_auc:0.875726
# epoch: 33, train_loss: 0.082544, train_auc:0.939583, test_auc:0.877431
# epoch: 34, train_loss: 0.136449, train_auc:0.941745, test_auc:0.868032
# epoch: 35, train_loss: 0.217524, train_auc:0.941716, test_auc:0.854982
# epoch: 36, train_loss: 0.162527, train_auc:0.947584, test_auc:0.863104
# epoch: 37, train_loss: 0.215799, train_auc:0.947162, test_auc:0.878097
# epoch: 38, train_loss: 0.188392, train_auc:0.951378, test_auc:0.868086
# epoch: 39, train_loss: 0.079441, train_auc:0.954594, test_auc:0.867850
# epoch: 40, train_loss: 0.163142, train_auc:0.954350, test_auc:0.883035
# epoch: 41, train_loss: 0.099241, train_auc:0.959865, test_auc:0.867124
# epoch: 42, train_loss: 0.105587, train_auc:0.961087, test_auc:0.882717
# epoch: 43, train_loss: 0.109480, train_auc:0.960187, test_auc:0.877791
# epoch: 44, train_loss: 0.125402, train_auc:0.963647, test_auc:0.865941
# epoch: 45, train_loss: 0.122149, train_auc:0.965489, test_auc:0.880060
# epoch: 46, train_loss: 0.120321, train_auc:0.963999, test_auc:0.880229
# epoch: 47, train_loss: 0.117766, train_auc:0.968829, test_auc:0.863547
# epoch: 48, train_loss: 0.178511, train_auc:0.969804, test_auc:0.873140
# epoch: 49, train_loss: 0.103636, train_auc:0.970122, test_auc:0.881934
# epoch: 50, train_loss: 0.053518, train_auc:0.984233, test_auc:0.903695
# epoch: 51, train_loss: 0.062742, train_auc:0.988328, test_auc:0.903636
# epoch: 52, train_loss: 0.115070, train_auc:0.989729, test_auc:0.903454
# epoch: 53, train_loss: 0.082162, train_auc:0.990694, test_auc:0.903686
# epoch: 54, train_loss: 0.063631, train_auc:0.991643, test_auc:0.902213
# epoch: 55, train_loss: 0.022069, train_auc:0.992530, test_auc:0.903637
# epoch: 56, train_loss: 0.049874, train_auc:0.993530, test_auc:0.903708
# epoch: 57, train_loss: 0.042657, train_auc:0.993467, test_auc:0.902659
# epoch: 58, train_loss: 0.056460, train_auc:0.993008, test_auc:0.901358
# epoch: 59, train_loss: 0.040534, train_auc:0.993883, test_auc:0.901526
# epoch: 60, train_loss: 0.055513, train_auc:0.993931, test_auc:0.902299
# epoch: 61, train_loss: 0.107208, train_auc:0.994011, test_auc:0.902856
# epoch: 62, train_loss: 0.065208, train_auc:0.994641, test_auc:0.900847
# epoch: 63, train_loss: 0.102017, train_auc:0.994941, test_auc:0.899437
# epoch: 64, train_loss: 0.062046, train_auc:0.994908, test_auc:0.901820
# epoch: 65, train_loss: 0.045315, train_auc:0.995219, test_auc:0.902808
# epoch: 66, train_loss: 0.058409, train_auc:0.995802, test_auc:0.901320
# epoch: 67, train_loss: 0.065060, train_auc:0.995385, test_auc:0.900376
# epoch: 68, train_loss: 0.082804, train_auc:0.995896, test_auc:0.902529
# epoch: 69, train_loss: 0.052917, train_auc:0.995679, test_auc:0.901329
# epoch: 70, train_loss: 0.020041, train_auc:0.995879, test_auc:0.901120
# epoch: 71, train_loss: 0.045228, train_auc:0.996561, test_auc:0.901837
# epoch: 72, train_loss: 0.058226, train_auc:0.997087, test_auc:0.899276
# epoch: 73, train_loss: 0.059246, train_auc:0.996859, test_auc:0.900831
# epoch: 74, train_loss: 0.052449, train_auc:0.997215, test_auc:0.902772
# epoch: 75, train_loss: 0.011279, train_auc:0.997423, test_auc:0.901753
# epoch: 76, train_loss: 0.038507, train_auc:0.997809, test_auc:0.901989
# epoch: 77, train_loss: 0.054725, train_auc:0.997751, test_auc:0.900804
# epoch: 78, train_loss: 0.014558, train_auc:0.997885, test_auc:0.901416
# epoch: 79, train_loss: 0.079849, train_auc:0.997722, test_auc:0.901330
# epoch: 80, train_loss: 0.031148, train_auc:0.997835, test_auc:0.900449
# epoch: 81, train_loss: 0.060018, train_auc:0.997964, test_auc:0.900666
# epoch: 82, train_loss: 0.040786, train_auc:0.997790, test_auc:0.901257
# epoch: 83, train_loss: 0.038571, train_auc:0.998013, test_auc:0.900654
# epoch: 84, train_loss: 0.030051, train_auc:0.997881, test_auc:0.901321
# epoch: 85, train_loss: 0.029722, train_auc:0.998032, test_auc:0.901619
# epoch: 86, train_loss: 0.040545, train_auc:0.997739, test_auc:0.900946
# epoch: 87, train_loss: 0.028282, train_auc:0.997799, test_auc:0.901690
# epoch: 88, train_loss: 0.068640, train_auc:0.997872, test_auc:0.900241
# epoch: 89, train_loss: 0.025386, train_auc:0.997851, test_auc:0.900808
# epoch: 90, train_loss: 0.031832, train_auc:0.997767, test_auc:0.900902
# epoch: 91, train_loss: 0.016300, train_auc:0.997686, test_auc:0.901258
# epoch: 92, train_loss: 0.028487, train_auc:0.997830, test_auc:0.900832
# epoch: 93, train_loss: 0.025274, train_auc:0.998299, test_auc:0.901468
# epoch: 94, train_loss: 0.021220, train_auc:0.998025, test_auc:0.901089
# epoch: 95, train_loss: 0.047234, train_auc:0.998134, test_auc:0.901270
# epoch: 96, train_loss: 0.028629, train_auc:0.998447, test_auc:0.901167
# epoch: 97, train_loss: 0.032166, train_auc:0.998258, test_auc:0.901273
# epoch: 98, train_loss: 0.056832, train_auc:0.998180, test_auc:0.900438
# epoch: 99, train_loss: 0.037052, train_auc:0.998002, test_auc:0.901083
